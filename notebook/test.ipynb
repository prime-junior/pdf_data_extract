# %%
import pandas as pd
import re
import os

# %% [markdown]
# ### Join the directory and the file name

# %%
# .pdf file dir 
dir = r'C:\Language_Projects\Language_Projects\Python\Flagship_1\pdf_data_extract\data'

# %%
data_dir = os.path.join(os.getcwd, f'C:\Language_Projects\Language_Projects\Python\Flagship_1\pdf_data_extract\data')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_8008\2908668559.py:1: SyntaxWarning: invalid escape sequence '\L'
#   data_dir = os.path.join(os.getcwd, f'C:\Language_Projects\Language_Projects\Python\Flagship_1\pdf_data_extract\data')
# C:\Users\Weverson Barbieri\AppData\Local\Temp\ipykernel_8008\2908668559.py:1: SyntaxWarning: invalid escape sequence '\L'
#   data_dir = os.path.join(os.getcwd, f'C:\Language_Projects\Language_Projects\Python\Flagship_1\pdf_data_extract\data')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data_dir = os.path.join(os.getcwd, f'C:\Language_Projects\Language_Projects\Python\Flagship_1\pdf_data_extract\data')
#
# File <frozen ntpath>:108, in join(path, *paths)
#
# TypeError: expected str, bytes or os.PathLike object, not builtin_function_or_method

# %%
# Iteration to print all file names and their extensions
for filename in os.listdir(dir):
    print(filename)
# Out:
# chrysler_pdf_extracted.xlsx
# chrysler_pdf_extract_to_csv.csv
# part_number_chart.pdf

# %%
# Iterate under dir data to have all files 
for filename in os.listdir(dir):
    # Condition to confirm which file has .pdf extension
    if filename.endswith('.pdf'):
        # Join the dir + filename when .pdf extension
        pdf_file_fullpath = os.path.join(dir, filename)
        # Print the result
        print(pdf_file_fullpath)
# Out:
# C:\Language_Projects\Language_Projects\Python\Flagship_1\pdf_data_extract\data\part_number_chart.pdf

# %%
# Example of data to extract
data = ['98 LH EATXIIIA WITHOUT AUTOSTICK\nLH', '95 BC EATXIIIA WITHOUT AUTOSTICK', '2003 EATXIIIA WITHOUT LA AUTOSTICK']

# %%
# Convert to df 
df = pd.DataFrame(data)

# %%
# Print the df
df
# Out:
#                                       0
# 0  98 LH EATXIIIA WITHOUT AUTOSTICK\nLH
# 1      95 BC EATXIIIA WITHOUT AUTOSTICK
# 2    2003 EATXIIIA WITHOUT LA AUTOSTICK

# %%
# Create a pattern to identify the body code
pattern = r'\s+([A-Z][A-Z0-9])\s+'

# %%
# List to store the positions and the body codes
positions = []

# Iterate under column 0 to get the text
for idx, text in df[0].items():
    # Iterate under the whole text and use the regex pattern to capture the body code 
    for match in re.finditer(pattern, text):
        # Append body code and the start position of the body code
        positions.append({
            'index': idx,
            'BC': match.group(1),
            'start_pos': match.start(1),
        })

# %%
# Print the list
positions
# Out:
# [{'index': 0, 'BC': 'LH', 'start_pos': 3},
#  {'index': 1, 'BC': 'BC', 'start_pos': 3},
#  {'index': 2, 'BC': 'LA', 'start_pos': 22}]

# %%
positions[1]
# Out:
# {'index': 1, 'BC': 'BC', 'start_pos': 3}

# %%
# Convert the list to df
df_positions = pd.DataFrame(positions)

# %%
# Print the df
df_positions
# Out:
#    index  BC  start_pos
# 0      0  LH          3
# 1      1  BC          3
# 2      2  LA         22

# %%
# Concate the df with the body code and position with the original df
# axis=1 is used to indicate the df will be concatenated horizontally, that is, with the columns side by side 
df_concatenated = pd.concat([df, df_positions], axis=1)

# %%
# Print the df concatenated
df_concatenated
# Out:
#                                       0  index  BC  start_pos
# 0  98 LH EATXIIIA WITHOUT AUTOSTICK\nLH      0  LH          3
# 1      95 BC EATXIIIA WITHOUT AUTOSTICK      1  BC          3
# 2    2003 EATXIIIA WITHOUT LA AUTOSTICK      2  LA         22

# %% [markdown]
# #### JOINING MULTIPLE BODY CODES AT THE SAME ROW

# %%
body_code1 = 'LA'

# %%
body_code2 = 'BC'

# %%
# Join the above strings
body_code = ', '.join([body_code1, body_code2])

# %%
# Print the strings joined
body_code
# Out:
# 'LA, BC'

# %%
# Data example
data = {
    'index': [14, 229, 229, 229, 230, 230],
    'BC': ['LA', 'BC', 'A3', 'B1', 'B2', 'C1']
    }

# %%
# Convert to df
df = pd.DataFrame(data)

# %%
# Print the df
df
# Out:
#    index  BC
# 0     14  LA
# 1    229  BC
# 2    229  A3
# 3    229  B1
# 4    230  B2
# 5    230  C1

# %%
# Print the df after checked marked
df
# Out:
#    index  BC
# 0     14  LA
# 1    229  BC
# 2    229  A3
# 3    229  B1
# 4    230  B2
# 5    230  C1

# %%
# groupby method group data from the same column to one and agg method indicates the next data should be grouped from
df.groupby(['index']).agg({'BC': list})
# Out:
#                  BC
# index
# 14             [LA]
# 229    [BC, A3, B1]
# 230        [B2, C1]

# %% [markdown]
# #### Compare 2 lists and find matches

# %%
# Create a list with examples of bcs
bc_list1 = ['A1', 'BC', 'B2', 'B1', '11']

# %%
# Create a second list 
bc_list2 = ['BC', 'A1', 'B1', 'BA', '20']

# %%
# Create a list with items that are in both lists
match_bc_list = []

# Iterate under the first list
for bc in bc_list1:
    # Iterate under the 2nd lit
    for bc1 in bc_list2:
        # Condition to confirm whether the bcs match
        if bc == bc1:
            # Append the matched bcs
            match_bc_list.append(bc)

# %%
# Print the match list
match_bc_list
# Out:
# ['A1', 'BC', 'B1']

# %% [markdown]
# #### Test merge method to merge 2 different dfs with different sizes

# %%
# Data example 1
data1 = {
    'index': [0, 1, 2, 3, 4],
    'Year': ['A1', pd.NA, 'B2', pd.NA, '11']
    }

# %%
# Data example 2
data2 = {
    'index': [1, 3],
    'Year': ['BC, CB', 'B1']
    }

# %%
# Convert both data examples to df
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
# Merge both dfs
# on - is the column reference or the column which matches in both dfs
# outer: use union of keys from both frames
dfs_merged = df1.merge(df2, how='outer', on='index')

# %%
dfs_merged
# Out:
#    index Year_x  Year_y
# 0      0     A1     NaN
# 1      1   <NA>  BC, CB
# 2      2     B2     NaN
# 3      3   <NA>      B1
# 4      4     11     NaN

# %%
dfs_merged['Year_x'] = dfs_merged['Year_x'].fillna(dfs_merged['Year_y'])

# %%
dfs_merged
# Out:
#    index  Year_x  Year_y
# 0      0      A1     NaN
# 1      1  BC, CB  BC, CB
# 2      2      B2     NaN
# 3      3      B1      B1
# 4      4      11     NaN

# %% [markdown]
# ### TEST A REMOVE DUPES AND COMBINE DOUBLE CODES METHOD

# %%
# Create a df for testing the method
data = pd.DataFrame( 
    data=[['BC, B1, B1'], ['W2, WK, WK'], ['']],
    index=[2002, 2011, 2012],
    columns=['bc']
    )

# %%
# Print the df
data
# Out:
#               bc
# 2002  BC, B1, B1
# 2011  W2, WK, WK
# 2012

# %%
# Body code pattern
bc_pattern = r'[A-Z0-9]{2}'

# %%
# Create a list with unique body codes
unique_bc_list = []

# Iterate under column bc to get the string with the bcs
for bc in data['bc']:
    # Method findall find the matches based on the pattern
    bc_matches = re.findall(bc_pattern, bc)
    if bc != '':
        bc_unique = list(set(bc_matches))
        bc_out_of_list = ', '.join(bc_unique)
        unique_bc_list.append(bc_out_of_list)
    else:
        unique_bc_list.append(bc)

# %%
# Print the list
unique_bc_list
# Out:
# ['B1, BC', 'WK, W2', '']

# %%
# Update the df after removing the duplicated bcs
data['bc'] = unique_bc_list

# %%
# Print the updated df
data
# Out:
#           bc
# 2002  B1, BC
# 2011  WK, W2
# 2012

# %% [markdown]
# ### dateparser

# %%
# List comprehension to create a big list only with valid years 
years_valid = [str(year) for year in range(94, 100)] + [str(year) for year in range(1994, 2027)]

# %%
# Create a list to save the year (s) found in each row
years_list = []

# Loop to iterate over the rows from col 'CALIBRATION'
for row in df_dropped_columns['CALIBRATION']:
    # Sub list to store matched years before joining in the same row
    years_sub_list = []
    # Search for years in each row and store as a list of tuples in the variable
    years_matched = search_dates(row)
    # Condition to confirm when finding years in the row
    if years_matched:
        # Loop to iterate over the list,
        # and access the tuple items
        for year in years_matched:
            # Access the first element of the tuple 
            years_str = year[0]
            # Regex to caputure only years and remove letters from the years
            years_matched = re.match(r"(9[4-9]|20[0-1][0-9]|202[0-6])", years_str)
            # Condition confirming when years were capture before apply .group() method,
            # to return year string
            if years_matched:
                year_grouped = years_matched.group()
                # Condition to confirm if the year is valid,
                # and then append to 'years_sub_list'
                if year_grouped in years_valid:
                    # Append years from the same row to the year sub list
                    years_sub_list.append(year_grouped)
                    print(year_grouped)
    # Append the years to the main list,
    # and use join to append without outside a list
    years_list.append(' '.join(years_sub_list))

# %%
def extract_year_list(df, pattern):
    year_list = []
    for row in df['CALIBRATION']:
        year_sub_list = []
        year_matched = re.match(pattern, row)
        if year_matched:
            year_sub_list.append(year_matched.group())
    
        year_list.append(' '.join(year_sub_list))

    return year_list
